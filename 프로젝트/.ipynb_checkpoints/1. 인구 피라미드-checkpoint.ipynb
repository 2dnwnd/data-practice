# %% [markdown]
# # 1. 인구 피라미드

# %% [markdown]
# ## 남자 데이터

# %%
import pandas as pd
# 남자 데이터
file_name = '202205_202205_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,E:Y')
df_m.head(3)
# Out:
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       1,198,172  1,207,585  1,599,070  1,869,118  1,711,521  1,760,776
# 서울특별시      216,517    210,493    276,664    340,569    341,230    413,485
# 부산광역시       67,855     68,576     97,550    127,154    124,510    122,771
#
#             30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                 ...
# 전국       2,073,285  2,122,334  2,348,899  2,175,736  ...  1,621,990
# 서울특별시      478,161    445,037    464,112    411,676  ...    334,415
# 부산광역시      139,353    132,547    148,018    144,287  ...    137,873
#
#             60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세 95~99세  \
# 행정기관
# 전국       1,165,741  891,532  741,383  451,137  200,938  78,881  24,234  4,974
# 서울특별시      244,336  191,755  144,990   76,604   33,283  13,479   4,926  1,231
# 부산광역시      102,391   74,506   56,752   30,848   12,761   4,375   1,232    252
#
#         100세 이상
# 행정기관
# 전국        2,777
# 서울특별시       939
# 부산광역시       240
#
# [3 rows x 21 columns]

# %%
# 콤마 문자로 인식할 수 이썽서 숫자로 바꾸기
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int)

# %%
df_m.iloc[0]
# Out:
# 0~4세       1198172
# 5~9세       1207585
# 10~14세     1599070
# 15~19세     1869118
# 20~24세     1711521
# 25~29세     1760776
# 30~34세     2073285
# 35~39세     2122334
# 40~44세     2348899
# 45~49세     2175736
# 50~54세     2195638
# 55~59세     1621990
# 60~64세     1165741
# 65~69세      891532
# 70~74세      741383
# 75~79세      451137
# 80~84세      200938
# 85~89세       78881
# 90~94세       24234
# 95~99세        4974
# 100세 이상       2777
# Name: 전국  , dtype: object

# %% [markdown]
# ## 여자 데이터

# %%
# 여자 데이터
df_w = pd.read_excel(file_name,
                     skiprows=3, index_col='행정기관', usecols='B,AB:AV')
df_w.head(3)
# Out:
#             0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국       1,129,060  1,121,396  1,465,153  1,656,457  1,537,488  1,653,792
# 서울특별시      204,668    197,929    255,648    307,415    336,299    421,862
# 부산광역시       64,380     63,569     87,600    108,202    110,117    115,800
#
#           30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                 ...
# 전국       1,989,544  2,042,452  2,264,185  2,069,661  ...  1,636,447
# 서울특별시      470,272    431,062    458,791    410,729  ...    361,440
# 부산광역시      133,307    128,579    149,794    148,779  ...    144,382
#
#           60~64세.1   65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국       1,215,014  1,010,384  953,529  715,809  439,376  213,337   76,800
# 서울특별시      263,508    207,922  164,435  110,761   68,312   35,495   13,473
# 부산광역시      107,907     80,560   70,080   48,033   29,499   13,629    4,336
#
#         95~99세.1 100세 이상.1
# 행정기관
# 전국        19,704     9,247
# 서울특별시      4,029     2,763
# 부산광역시      1,182       876
#
# [3 rows x 21 columns]

# %%
# column  0~4세.1 삭제
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns # 컬럼명 통일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
# 콤마 문자로 인식할 수 이썽서 숫자로 바꾸기
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1129060  1121396  1465153  1656457  1537488  1653792  1989544
# 서울특별시      204,668  197,929  255,648  307,415  336,299  421,862  470,272
# 부산광역시       64,380   63,569   87,600  108,202  110,117  115,800  133,307
# 대구광역시       50,128   52,854   73,712   85,543   74,869   76,264   92,620
# 인천광역시       65,372   63,607   82,144   97,369   93,146   94,842  113,181
# 광주광역시       34,872   37,200   51,742   57,087   47,832   49,008   59,096
# 대전광역시       36,149   37,451   47,987   53,960   49,156   51,478   61,965
# 울산광역시       27,596   26,143   35,690   40,928   34,015   34,784   44,545
# 경기도        303,532  303,707  378,487  408,805  368,485  384,945  494,502
# 강원도         30,261   32,419   44,032   48,982   42,181   38,972   48,350
# 충청북도        35,528   35,147   46,726   51,266   44,221   45,920   54,607
# 충청남도        50,565   48,361   61,254   65,039   58,333   60,681   73,830
# 전라북도        39,111   41,202   56,837   63,412   53,103   50,484   59,407
# 전라남도        39,270   39,192   54,716   61,305   48,826   46,299   55,011
# 경상북도        55,240   53,131   70,810   79,356   71,788   73,358   88,476
# 경상남도        78,261   74,727   98,457  107,337   89,136   93,240  120,589
# 제주특별자치도     14,127   14,757   19,311   20,451   15,981   15,855   19,786
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         2042452  2264185  2069661  ...  1636447  1215014  1010384   953529
# 서울특별시      431,062  458,791  410,729  ...  361,440  263,508  207,922  164,435
# 부산광역시      128,579  149,794  148,779  ...  144,382  107,907   80,560   70,080
# 대구광역시      100,443  117,967  111,273  ...   85,534   64,447   48,829   45,387
# 인천광역시      115,350  130,895  125,667  ...   84,610   56,582   46,439   41,108
# 광주광역시       62,199   67,122   59,506  ...   40,345   32,547   25,507   22,780
# 대전광역시       64,498   71,122   62,056  ...   46,197   31,785   24,706   22,294
# 울산광역시       46,214   55,991   51,773  ...   34,859   22,134   15,304   13,114
# 경기도        534,753  585,243  506,081  ...  331,411  230,288  196,435  177,964
# 강원도         54,117   61,291   60,188  ...   54,429   38,957   38,985   40,052
# 충청북도        58,183   65,501   60,692  ...   50,269   36,225   33,549   35,346
# 충청남도        77,504   82,124   75,459  ...   64,810   53,583   46,873   52,577
# 전라북도        65,782   72,996   69,743  ...   59,701   52,183   46,215   49,914
# 전라남도        59,348   68,517   68,591  ...   59,849   56,043   54,963   63,582
# 경상북도        93,522  104,818  103,329  ...   95,609   75,908   65,791   73,892
# 경상남도       128,678  145,935  132,826  ...  105,927   79,709   66,271   69,398
# 제주특별자치도     22,220   26,078   22,969  ...   17,075   13,208   12,035   11,606
#
#             75~79세  80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          715809  439376  213337   76800  19704    9247
# 서울특별시      110,761  68,312  35,495  13,473  4,029   2,763
# 부산광역시       48,033  29,499  13,629   4,336  1,182     876
# 대구광역시       32,725  18,980   8,614   2,927    692     303
# 인천광역시       30,718  19,598   9,727   3,432    848     350
# 광주광역시       16,450  10,438   5,170   1,984    493     226
# 대전광역시       16,723  10,258   5,047   1,729    472     178
# 울산광역시        9,726   6,174   3,169   1,015    247      75
# 경기도        131,309  79,058  39,196  14,235  3,581   1,590
# 강원도         28,498  18,267   9,187   3,317    821     307
# 충청북도        29,047  16,931   7,974   2,890    705     219
# 충청남도        44,997  26,412  12,675   4,567  1,114     439
# 전라북도        40,881  25,056  11,456   4,445  1,080     416
# 전라남도        49,795  31,883  14,883   5,526  1,407     522
# 경상북도        59,691  36,290  17,422   6,307  1,473     416
# 경상남도        56,548  35,943  16,373   4,960  1,033     411
# 제주특별자치도      9,907   6,277   3,320   1,657    527     156
#
# [17 rows x 21 columns]

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0]//1000) # 단위 : 천명
plt.barh(df_w.columns, df_w.iloc[0]//1000) # 단위 : 천명
plt.title('2022년 대한민국 인구 피라미드')
plt.savefig('2021_인구피라미드.png', dpi=100)
plt.show()
